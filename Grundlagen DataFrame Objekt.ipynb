# %%
import pandas as pd

# %% [markdown]
# # Das DataFrame Objekt

# %%
ds_guests = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/daily-show-guests/daily_show_guests.csv", 
                                encoding="unicode_escape", header=0)

# %%
ds_guests.head()
# Out:
#    YEAR GoogleKnowlege_Occupation     Show   Group    Raw_Guest_List
# 0  1999                     actor  1/11/99  Acting    Michael J. Fox
# 1  1999                  Comedian  1/12/99  Comedy   Sandra Bernhard
# 2  1999        television actress  1/13/99  Acting     Tracey Ullman
# 3  1999              film actress  1/14/99  Acting  Gillian Anderson
# 4  1999                     actor  1/18/99  Acting  David Alan Grier

# %%
#By default rename creates a new DataFrame, remember to use inplace=True if you do not want to create a new object
ds_guests.rename(columns={'Raw_Guest_List':'Guest',
                         'GoogleKnowlege_Occupation':'Occupation',
                         'Show':'Date'}, inplace=True)

# %%
ds_guests.head()
# Out:
#    YEAR          Occupation     Date   Group             Guest
# 0  1999               actor  1/11/99  Acting    Michael J. Fox
# 1  1999            Comedian  1/12/99  Comedy   Sandra Bernhard
# 2  1999  television actress  1/13/99  Acting     Tracey Ullman
# 3  1999        film actress  1/14/99  Acting  Gillian Anderson
# 4  1999               actor  1/18/99  Acting  David Alan Grier

# %%
ds_guests.columns
# Out:
# Index(['YEAR', 'Occupation', 'Date', 'Group', 'Guest'], dtype='object')

# %%
ds_guests.index
# Out:
# RangeIndex(start=0, stop=2693, step=1)

# %%
ds_guests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 5 columns):
# YEAR          2693 non-null int64
# Occupation    2667 non-null object
# Date          2693 non-null object
# Group         2662 non-null object
# Guest         2693 non-null object
# dtypes: int64(1), object(4)
# memory usage: 105.3+ KB

# %% [markdown]
# ## Selektion (Teil 1)

# %%
#Attribute access (special consideration for naming e.g.: min, index, and whitespaces)
ds_guests.Group.head()
# Out:
# 0    Acting
# 1    Comedy
# 2    Acting
# 3    Acting
# 4    Acting
# Name: Group, dtype: object

# %%
#Standard Access
ds_guests["Group"].head()
# Out:
# 0    Acting
# 1    Comedy
# 2    Acting
# 3    Acting
# 4    Acting
# Name: Group, dtype: object

# %%
#Mehrere Spalten
ds_guests[["Group", "Date"]].head()
# Out:
#     Group     Date
# 0  Acting  1/11/99
# 1  Comedy  1/12/99
# 2  Acting  1/13/99
# 3  Acting  1/14/99
# 4  Acting  1/18/99

# %%
#Integer-location index
ds_guests["Group"].iloc[1:5]
# Out:
# 1    Comedy
# 2    Acting
# 3    Acting
# 4    Acting
# Name: Group, dtype: object

# %%
# Wie auch bei Series Objekten kann eine Selektion ebenfalls über eine True/False Serie erfolgen  
ds_guests[ds_guests["Group"] == "Acting"].head()
# Out:
#    YEAR          Occupation     Date   Group             Guest
# 0  1999               actor  1/11/99  Acting    Michael J. Fox
# 2  1999  television actress  1/13/99  Acting     Tracey Ullman
# 3  1999        film actress  1/14/99  Acting  Gillian Anderson
# 4  1999               actor  1/18/99  Acting  David Alan Grier
# 5  1999               actor  1/19/99  Acting   William Baldwin

# %%
# Über die True/False Selektion können auch Konditionen abgebildet werden  
ds_guests[(ds_guests["Group"] == "Acting") & (ds_guests["Occupation"] == "actor")].head()
# Out:
#     YEAR Occupation     Date   Group             Guest
# 0   1999      actor  1/11/99  Acting    Michael J. Fox
# 4   1999      actor  1/18/99  Acting  David Alan Grier
# 5   1999      actor  1/19/99  Acting   William Baldwin
# 8   1999      actor  1/25/99  Acting   Matthew Lillard
# 11  1999      actor  1/28/99  Acting     D. L. Hughley

# %%
# Über die Kombination unique und (Array-) Length lassen sich alle disjunkten Elemente zählen 
len(ds_guests.Occupation.unique())
# Out:
# 399

# %%
len(ds_guests.Group.unique())
# Out:
# 18

# %% [markdown]
# ## DataFrame Modifikationen

# %%
#Same applies to drop
ds_guests.drop(columns=['YEAR'], inplace=True)

# %%
#Create a new column which uses the number of whitespaces to estimate the number of forenames 
ds_guests["Forename Number"] = ds_guests.Guest.apply(lambda guest: (len(guest.split(" ")) - 1))

# %%
#Get descriptive statistics for the number of forenames
ds_guests["Forename Number"].describe()
# Out:
# count    2693.000000
# mean        1.242481
# std         0.893401
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        15.000000
# Name: Forename Number, dtype: float64

# %% [markdown]
# ### What guest name has 15 forenames?

# %%
ds_guests[ds_guests["Forename Number"] == 15].Guest.values
# Out:
# array(['Iraq - A Look Baq (or how we learned to stop reporting and love the war)',
#        'Iraq - A Look Baq (or how we learned to stop reporting and love the war)'],
#       dtype=object)

# %%
#Filter out the rows with the the identified 16 word string 
ds_guests = ds_guests[ds_guests.Guest != 'Iraq - A Look Baq (or how we learned to stop reporting and love the war)']

# %%
ds_guests["Forename Number"].describe()
# Out:
# count    2691.000000
# mean        1.232256
# std         0.811131
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        12.000000
# Name: Forename Number, dtype: float64

# %% [markdown]
# ## Aufgaben:

# %% [markdown]
#     - Welcher Gast hat 12 Vornamen?
#     - Identifiziere anhand der Vornamenanzahl alle Gast Namen, die keine natürlichen Personen darstellen (setze 5 als obere Grenze für die Vornahmenanzahl) ?
#     - Gibt es Duplikate in unserem Datensatz? Nutze hierzu die Funktion "duplicated" und oder "drop_duplicates".
#     - Welcher Gast gehört keiner Gruppe an? Welcher Gast gehört keiner Occupation an? Nutze hierzu die Funktion pd.isnull und oder pd.notnull
#     - Welche Spalte bietet sich als Index an?
#     - Wieviele unterschiedliche Gäste gab es in der Gruppe ("Group") Politician ?
#     - Wann war Vin Diesel zu Gast?
#     - Wann und wie oft war Will Ferrell zu Gast? Tipp: Er war öfter als 10 mal da.

# %% [markdown]
# ## Selektion (Teil 2)

# %%
ds_guests["Date"] = pd.to_datetime(ds_guests.Date)
ds_guests.set_index("Date", inplace=True)

# %%
#Index basierter Zugriff via loc
ds_guests.loc['2011-08-10']
# Out:
#            Occupation Group        Guest  Forename Number
# Date
# 2011-08-10     lawyer  Misc  John Coffee                1

# %%
#Datum kann auch via Default Notation verwendet werden
ds_guests['2011-08-10']
# Out:
#            Occupation Group        Guest  Forename Number
# Date
# 2011-08-10     lawyer  Misc  John Coffee                1

# %%
ds_guests['2010':'2011']
# Out:
#                                         Occupation       Group  \
# Date
# 2010-01-11                                  lawyer        Misc
# 2010-01-12                                  Editor       Media
# 2010-01-13                                musician    Musician
# 2010-01-13                               rock band    Musician
# 2010-01-14                              Journalist       Media
# 2010-01-18                   comptroller of the us  Government
# 2010-01-19                                   actor      Acting
# 2010-01-20                                  writer       Media
# 2010-01-21                                 actress      Acting
# 2010-01-25                         busines magnate    Business
# 2010-01-26                              us senator  Politician
# 2010-01-27                              journalist       Media
# 2010-01-28                              biographer       Media
# 2010-01-04                                  Author       Media
# 2010-01-05                           film director       Media
# 2010-01-06                                military    Military
# 2010-01-07                                 actress      Acting
# 2010-10-11                         stunt perfomrer      Acting
# 2010-10-12                   former mjority leader  Politician
# 2010-10-13            former us secretary of state  Politician
# 2010-10-14                                  writer       Media
# 2010-10-25                               economist    Academic
# 2010-10-26            Former United States Senator  Politician
# 2010-10-27                               president  Politician
# 2010-10-28                                     NaN         NaN
# 2010-10-04                                  Author       Media
# 2010-10-05                                   actor      Acting
# 2010-10-06                                  Writer       Media
# 2010-10-07                                 actress      Acting
# 2010-11-01                       Stand-up comedian      Comedy
# ...                                            ...         ...
# 2011-07-25                                   actor      Acting
# 2011-07-26                              journalist       Media
# 2011-07-27                            Film actress      Acting
# 2011-07-28                                Diplomat  Government
# 2011-08-01                                 actress      Acting
# 2011-08-10                                  lawyer        Misc
# 2011-08-11                              Journalist       Media
# 2011-08-15                         television host       Media
# 2011-08-16                                   actor      Acting
# 2011-08-17  Former Lieutenant Governor of Maryland  Politician
# 2011-08-18                                 actress      Acting
# 2011-08-02                                   actor      Acting
# 2011-08-03                               economist    Academic
# 2011-08-04                              us senator  Politician
# 2011-08-08                                  author       Media
# 2011-08-09                              journalist       Media
# 2011-09-12                                 ADMIRAL    Military
# 2011-09-13                              journalist       Media
# 2011-09-14                          hip-hop artist    Musician
# 2011-09-15                                  author       Media
# 2011-09-20                              Journalist       Media
# 2011-09-21              Former Governor of Indiana  Politician
# 2011-09-22             former governor of michigan  Politician
# 2011-09-26                 Former U.S. Congressman  Politician
# 2011-09-27                                   actor      Acting
# 2011-09-28                         television host       Media
# 2011-09-29                                  Singer    Musician
# 2011-09-06            former governor of louisiana  Politician
# 2011-09-07                            neurosurgeon     Science
# 2011-09-08                                 actress      Acting
#
#                                           Guest  Forename Number
# Date
# 2010-01-11                             John Yoo                1
# 2010-01-12                       Paul Ingrassia                1
# 2010-01-13  Ringo Starr and The Ben Harper Band                6
# 2010-01-13  Ringo Starr and The Ben Harper Band                6
# 2010-01-14                           Tom Brokaw                1
# 2010-01-18                      David M. Walker                2
# 2010-01-19                          Colin Firth                1
# 2010-01-20                           Jim Wallis                1
# 2010-01-21                        Julie Andrews                1
# 2010-01-25                           Bill Gates                1
# 2010-01-26                     Elizabeth Warren                1
# 2010-01-27                        Ethan Watters                1
# 2010-01-28                 Doris Kearns Goodwin                2
# 2010-01-04                       Michael Pollan                1
# 2010-01-05                         George Lucas                1
# 2010-01-06                       Michael Mullen                1
# 2010-01-07                    Maggie Gyllenhaal                1
# 2010-10-11                     Johnny Knoxville                1
# 2010-10-12                          Eric Cantor                1
# 2010-10-13                     Condoleezza Rice                1
# 2010-10-14                         David Rakoff                1
# 2010-10-25                      Austan Goolsbee                1
# 2010-10-26                          Ted Kaufman                1
# 2010-10-27               President Barack Obama                2
# 2010-10-28                                 none                0
# 2010-10-04                           Sam Harris                1
# 2010-10-05                         Bruce Willis                1
# 2010-10-06                          Philip Dray                1
# 2010-10-07                          Naomi Watts                1
# 2010-11-01                    Zach Galifianakis                1
# ...                                         ...              ...
# 2011-07-25                  Neil Patrick Harris                2
# 2011-07-26                        Juan Williams                1
# 2011-07-27                         Rachel Weisz                1
# 2011-07-28                         Peter Tomsen                1
# 2011-08-01                         Freida Pinto                1
# 2011-08-10                          John Coffee                1
# 2011-08-11                       Michael Wallis                1
# 2011-08-15                           Ali Velshi                1
# 2011-08-16                            Matt Long                1
# 2011-08-17                       Michael Steele                1
# 2011-08-18                        Anne Hathaway                1
# 2011-08-02                        Jason Bateman                1
# 2011-08-03                      Austan Goolsbee                1
# 2011-08-04                          Dick Durbin                1
# 2011-08-08                           Mark Adams                1
# 2011-08-09                          Jay Bahadur                1
# 2011-09-12               Admiral Michael Mullen                2
# 2011-09-13                           Jim Lehrer                1
# 2011-09-14                               Common                0
# 2011-09-15                     Caroline Kennedy                1
# 2011-09-20                          Ron Suskind                1
# 2011-09-21                        Mitch Daniels                1
# 2011-09-22                    Jennifer Granholm                1
# 2011-09-26                             Ron Paul                1
# 2011-09-27                           Seth Rogen                1
# 2011-09-28                        Bill O'Reilly                1
# 2011-09-29                         Tony Bennett                1
# 2011-09-06                         Buddy Roemer                1
# 2011-09-07                     Dr. Sanjay Gupta                2
# 2011-09-08                     Marion Cotillard                1
#
# [328 rows x 4 columns]

# %% [markdown]
# ## GroupBy

# %%
#Native apply functions are sum, mean, max, min, count, first, last
ds_guests.groupby("Group").count()
# Out:
#                 Occupation  Guest  Forename Number
# Group
# Academic               103    103              103
# Acting                 930    930              930
# Advocacy                24     24               24
# Athletics               52     52               52
# Business                25     25               25
# Clergy                   8      8                8
# Comedy                 150    150              150
# Consultant              18     18               18
# Government              40     40               40
# Media                  751    751              751
# Military                16     16               16
# Misc                    45     45               45
# Musician               123    123              123
# Political Aide          36     36               36
# Politician             308    308              308
# Science                 28     28               28
# media                    5      5                5

# %% [markdown]
# # Aufgaben

# %% [markdown]
# - Erstelle eine Übersicht die angibt wie oft die einzelnen Gäste zu Besuch waren.
# - Wie lauten die Top 3 Gäste pro Kategorie?
# - Was waren die Top 3 Kategorien in der Zeitspanne 01.01.2006 - 01.01.2010 die am häufigsten vertreten waren?
# - Was waren die Top 3 Kategorien pro Jahr in der gesamten Zeitspanne (Tipp: Verwendet hierzu pd.Grouper)
# - Was waren die Top 10 Monate an denen am meisten Besucher zu Gast waren?
